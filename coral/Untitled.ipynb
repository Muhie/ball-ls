# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !conda install -q -y python=3.9.6
# Out:
# --2025-03-31 20:47:32--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# 2606:4700::6810:20f1, 2606:4700::6810:bf9e, 104.16.191.158, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|2606:4700::6810:20f1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 154615621 (147M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 147.45M  2.11MB/s    in 70s
#
# 2025-03-31 20:48:42 (2.10 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [154615621/154615621]
#
# PREFIX=/usr/local
# Miniconda3-latest-Linux-x86_64.sh: line 432: /usr/local/_conda: Permission denied
# Retrieving notices: ...working... done
# Channels:
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): ...working...
# doneing environment: ...working...
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - python=3.9.6
# ...
